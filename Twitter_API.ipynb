# %%
import requests
import os
import json

# %%
# %run keys.py

# %%
print(bearer_token)
# Out:
# AAAAAAAAAAAAAAAAAAAAADspYwEAAAAAUqJiF7RG6Ba7AvZBCXWs1DRd9hk%3DFyL0rjcnOE0UPR163zP77mUPxakjrDfpILf3q8cZ4yVNBQETDy

# %%
search_url= 'https://api.twitter.com/2/tweets/search/recent?query=Finance&max_results=30'

# %%
r= requests.get(search_url, headers= {'Authorization': 'Bearer '+bearer_token})

# %%
print(r.json())
# Out:
# {'data': [{'id': '1491284274569687040', 'text': 'RT @pushpendrakum: Link https://t.co/hHB6EilCdZ'}, {'id': '1491284265388343300', 'text': 'RT @Axolotl_Coin: Pre-Sale goes live tomorrow!\n\nhttps://t.co/zI2oi3eDDd'}, {'id': '1491284264893427713', 'text': 'RT @Xenos_Giveaway: $250 GIVEAWAY | 48 hours ‼️\n\nGiving $150,\n\n✅ RT + follow @SLAP_Finance + rt📌\n____________________\n\n- Bonus $100 join tg…'}, {'id': '1491284264314621955', 'text': 'RT @DRAGONVERSE_OA: Link Play\nhttps://t.co/c2PlZjC8oK\n\nGuides\nhttps://t.co/B3IAYsiPzC\n\nReward \nhttps://t.co/G097XbrGRx\n\nDeposit &amp; Withdraw…'}, {'id': '1491284263542878208', 'text': 'RT @ame_pay: ➡️ AMEPAY Product Live Demo\n\nYou often ask us about how AMEPAY works, and we have decided to make a video where we demonstrate…'}, {'id': '1491284262192283650', 'text': 'RT @ACYFinance: Learn how you can buy ACY FINANCE on Coinbase Wallet in six easy steps. Over 68 million people and businesses trust us to b…'}, {'id': '1491284261118578688', 'text': 'RT @concretecodes: Two for Tuesday? Good to see we are under #CoinMarketCap top gainers of the day and now on 3000 plus watch lists. https:…'}, {'id': '1491284261043077125', 'text': 'The @ExtendXYZ Genesis NFT Space Whitelist is Live! #IF IDIA https://t.co/OaVkRbbqqm #IDIA #Launchpad #BSC #BinanceSmartChain #Sol #Solana #ExtendXYZ #NFT #SolanaNFTs'}, {'id': '1491284258195120130', 'text': '@CryptonationN @portal_finance I see that the Fair Launch of LIST tokens will commence on the March 7th. Can you give more information about this Fair Launch? How long will the Fair Launch run for? Where will this Fair Launch take place? At what price will the LIST token be purchased during this Fair Launch?'}, {'id': '1491284255204585473', 'text': "RT @finshots: We're hosting a very special Twitter Space with the Finshots founders this Thursday, 7 pm IST.\n\nTune in to our live discussio…"}, {'id': '1491284255061999616', 'text': 'RT @AccoinCrypto: 💥 Token Sale is Live on Coinsbit 💥\n\n🌟 Dear users, buy now your ACCG token!\n\n🔹 Buy Now 👇\n\nhttps://t.co/W6vDuMbGuL\n\n#Coinsb…'}, {'id': '1491284252771553285', 'text': 'The @ExtendXYZ Genesis NFT Space Whitelist is Live! #IF IDIA https://t.co/DKv8S5gcHi #IDIA #Launchpad #BSC #BinanceSmartChain #Sol #Solana #ExtendXYZ #NFT #SolanaNFTs'}, {'id': '1491284252528422915', 'text': '**How much are you paying for your Project or Development Finance and how much deposit do you have to pay?**\n\nMy clients are just paying 1% Interest Rate Per Annum and its Fixed for 10 Years or more.\n\nPlus they only need 5% deposit, which is refundable o…https://t.co/OIvxliXJB7'}, {'id': '1491284252021125124', 'text': 'The @ExtendXYZ Genesis NFT Space Whitelist is Live! #IF IDIA https://t.co/gdxwCTBia6 #IDIA #Launchpad #BSC #BinanceSmartChain #Sol #Solana #ExtendXYZ #NFT #SolanaNFTs'}, {'id': '1491284250674753536', 'text': 'The @ExtendXYZ Genesis NFT Space Whitelist is Live! #IF IDIA https://t.co/PaLon7A9KX #IDIA #Launchpad #BSC #BinanceSmartChain #Sol #Solana #ExtendXYZ #NFT #SolanaNFTs'}, {'id': '1491284247839055872', 'text': 'RT @SmartMonkeyFIn: 🔥 $SMM Final Airdrop Claim🐒\n\n- Limited 300 000 $SMM To Be Claimed\nFree 🎁 100 ($SMM) Tokens \n🔹Open Trust wallet \n🔹Go to…'}, {'id': '1491284246442364929', 'text': '@ESPNcricinfo Linkka Finance $IKA\n\nA strong project really early on. Already listing on cmc, cg, binance, coinbase, audited by certik, no tax, doxxed team, e.t.c.✅\n\nDo your own research about @Linkka_Finance, buy &amp; hold now before pumping hard!🚀\n\nhttps://t.co/FAEeIBY1Gl\n\n-shilled by Ehsan'}, {'id': '1491284245981007872', 'text': "RT @fort_swap: 🚨🚨🚨🚨🚨🚨💰💰💰💰🔥🔥🔥⚠️⚠️⚠️⚠️⚠️⚠️⚠️\nOur pre-sale is now Live you can buy your token through this link: https://t.co/1xgoPJypk4\nDon't…"}, {'id': '1491284241828950017', 'text': '@atomic_finance Nice project and congratulations to the team for their efforts and dedication and highly appreciated the visionary thought of the projector and it will create history コルナit will go to moon ...

# %%
dir(r)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
r_j= r.json()

# %%
type(r_j)
# Out:
# dict

# %%
print(len(r_j['data']))
# Out:
# 30

# %%
import pandas as pd

# %%
df= pd.DataFrame.from_dict(r_j['data'])

# %%
df
# Out:
#                      id                                               text
# 0   1491284274569687040    RT @pushpendrakum: Link https://t.co/hHB6EilCdZ
# 1   1491284265388343300  RT @Axolotl_Coin: Pre-Sale goes live tomorrow!...
# 2   1491284264893427713  RT @Xenos_Giveaway: $250 GIVEAWAY | 48 hours ‼...
# 3   1491284264314621955  RT @DRAGONVERSE_OA: Link Play\nhttps://t.co/c2...
# 4   1491284263542878208  RT @ame_pay: ➡️ AMEPAY Product Live Demo\n\nYo...
# 5   1491284262192283650  RT @ACYFinance: Learn how you can buy ACY FINA...
# 6   1491284261118578688  RT @concretecodes: Two for Tuesday? Good to se...
# 7   1491284261043077125  The @ExtendXYZ Genesis NFT Space Whitelist is ...
# 8   1491284258195120130  @CryptonationN @portal_finance I see that the ...
# 9   1491284255204585473  RT @finshots: We're hosting a very special Twi...
# 10  1491284255061999616  RT @AccoinCrypto: 💥 Token Sale is Live on Coin...
# 11  1491284252771553285  The @ExtendXYZ Genesis NFT Space Whitelist is ...
# 12  1491284252528422915  **How much are you paying for your Project or ...
# 13  1491284252021125124  The @ExtendXYZ Genesis NFT Space Whitelist is ...
# 14  1491284250674753536  The @ExtendXYZ Genesis NFT Space Whitelist is ...
# 15  1491284247839055872  RT @SmartMonkeyFIn: 🔥 $SMM Final Airdrop Claim...
# 16  1491284246442364929  @ESPNcricinfo Linkka Finance $IKA\n\nA strong ...
# 17  1491284245981007872  RT @fort_swap: 🚨🚨🚨🚨🚨🚨💰💰💰💰🔥🔥🔥⚠️⚠️⚠️⚠️⚠️⚠️⚠️\nOu...
# 18  1491284241828950017  @atomic_finance Nice project and congratulatio...
# 19  1491284241661165570  @Xenos_Giveaway @SLAP_Finance Tg amelda https:...
# 20  1491284238263406592  @CryptonationN @portal_finance if we want to s...
# 21  1491284238091825153  RT @Lawtoken1: 📣#CoinTigerNewListing\n\n#LAW/U...
# 22  1491284238087634947  RT @beedexfinance: 👉 Free Airdrop get 5,000,00...
# 23  1491284237500108800  @CryptoCrowd2011 @IbgFinance Can you explain w...
# 24  1491284236783226880  The @ExtendXYZ Genesis NFT Space Whitelist is ...
# 25  1491284236573511681  #BlockX#digitalassets #finance $BCX #blockchai...
# 26  1491284235432652800  @Xenos_Giveaway @SLAP_Finance allahumma sholli...
# 27  1491284233708613632  100% assurance help in academic writing.\nGuar...
# 28  1491284233230307328  Thank you so much! 1 430 000 000 SHIB sent to ...
# 29  1491284232295305217  RT @gowswap: Welcome to GowSwap\n👉 Link Buy ID...

# %%
search_url= 'https://api.twitter.com/2/tweets/search/recent?query=Stonks&max_results=30'

# %%
r_2= requests.get(search_url, headers= {'Authorization': 'Bearer '+bearer_token})

# %%
df= df.append(pd.DataFrame.from_dict(r_2.json()['data']), ignore_index=True)

# %%
df
# Out:
#                      id                                               text
# 0   1491284274569687040    RT @pushpendrakum: Link https://t.co/hHB6EilCdZ
# 1   1491284265388343300  RT @Axolotl_Coin: Pre-Sale goes live tomorrow!...
# 2   1491284264893427713  RT @Xenos_Giveaway: $250 GIVEAWAY | 48 hours ‼...
# 3   1491284264314621955  RT @DRAGONVERSE_OA: Link Play\nhttps://t.co/c2...
# 4   1491284263542878208  RT @ame_pay: ➡️ AMEPAY Product Live Demo\n\nYo...
# 5   1491284262192283650  RT @ACYFinance: Learn how you can buy ACY FINA...
# 6   1491284261118578688  RT @concretecodes: Two for Tuesday? Good to se...
# 7   1491284261043077125  The @ExtendXYZ Genesis NFT Space Whitelist is ...
# 8   1491284258195120130  @CryptonationN @portal_finance I see that the ...
# 9   1491284255204585473  RT @finshots: We're hosting a very special Twi...
# 10  1491284255061999616  RT @AccoinCrypto: 💥 Token Sale is Live on Coin...
# 11  1491284252771553285  The @ExtendXYZ Genesis NFT Space Whitelist is ...
# 12  1491284252528422915  **How much are you paying for your Project or ...
# 13  1491284252021125124  The @ExtendXYZ Genesis NFT Space Whitelist is ...
# 14  1491284250674753536  The @ExtendXYZ Genesis NFT Space Whitelist is ...
# 15  1491284247839055872  RT @SmartMonkeyFIn: 🔥 $SMM Final Airdrop Claim...
# 16  1491284246442364929  @ESPNcricinfo Linkka Finance $IKA\n\nA strong ...
# 17  1491284245981007872  RT @fort_swap: 🚨🚨🚨🚨🚨🚨💰💰💰💰🔥🔥🔥⚠️⚠️⚠️⚠️⚠️⚠️⚠️\nOu...
# 18  1491284241828950017  @atomic_finance Nice project and congratulatio...
# 19  1491284241661165570  @Xenos_Giveaway @SLAP_Finance Tg amelda https:...
# 20  1491284238263406592  @CryptonationN @portal_finance if we want to s...
# 21  1491284238091825153  RT @Lawtoken1: 📣#CoinTigerNewListing\n\n#LAW/U...
# 22  1491284238087634947  RT @beedexfinance: 👉 Free Airdrop get 5,000,00...
# 23  1491284237500108800  @CryptoCrowd2011 @IbgFinance Can you explain w...
# 24  1491284236783226880  The @ExtendXYZ Genesis NFT Space Whitelist is ...
# 25  1491284236573511681  #BlockX#digitalassets #finance $BCX #blockchai...
# 26  1491284235432652800  @Xenos_Giveaway @SLAP_Finance allahumma sholli...
# 27  1491284233708613632  100% assurance help in academic writing.\nGuar...
# 28  1491284233230307328  Thank you so much! 1 430 000 000 SHIB sent to ...
# 29  1491284232295305217  RT @gowswap: Welcome to GowSwap\n👉 Link Buy ID...
# 30  1491300409235079169  RT @RudeKidzNFT: Here are the 25 winners, 25 o...
# 31  1491299874046103554  RT @SynthwaveMafia: Happy to announce that we ...
# 32  1491298961315233795  RT @RudeKidzNFT: Here are the 25 winners, 25 o...
# 33  1491298278113439753                            stonks we’re good today
# 34  1491297341722488836  RT @RudeKidzNFT: Here are the 25 winners, 25 o...
# 35  1491297259413471232                       @GarisBalap marketing stonks
# 36  1491297182762545152  RT @CryptoNostra: Do you invest in stonks ?🤑\n...
# 37  1491296717295452160  RT @RudeKidzNFT: Here are the 25 winners, 25 o...
# 38  1491296492308799488  RT @RudeKidzNFT: Here are the 25 winners, 25 o...
# 39  1491296274876084232                        @CuteMokona y'all... stonks
# 40  1491295933367463936  RT @Trader4lyf: Often the nosiest trader in th...
# 41  1491295783358177281  RT @RudeKidzNFT: Here are the 25 winners, 25 o...
# 42  1491295689862950912  Wordle 235 4/6\n\n⬛⬛⬛🟩⬛\n⬛🟩⬛🟩🟩\n⬛🟩🟩🟩🟩\n🟩🟩🟩🟩🟩\n...
# 43  1491294306841554945  RT @CarlosR: so today i had to approve many we...
# 44  1491294293503483906  🌟\n.\n.\n.\n.\n.\n.\n\n#capitalvedaa #financem...
# 45  1491293062546739200                          @adi_thatipalli Stonks 📈📈
# 46  1491293040048480256  @Konekoris IRRY STONKS SOALNYA ANAK AK MUSTI B...
# 47  1491291342647218177  RT @RudeKidzNFT: Here are the 25 winners, 25 o...
# 48  1491290773710585859  Stock market mounts up for record growth as Bo...
# 49  1491290283094405123       @alfonsinaviera_ literalmente esto es stonks
# 50  1491290272889978880  RT @RudeKidzNFT: Here are the 25 winners, 25 o...
# 51  1491290166937657344  Inazuma Social Credits go stonks https://t.co/...
# 52  1491289282166030338  RT @ali_moiz: Director's cut: @Stonks_dot_com ...
# 53  1491288823585984519  @Phil_up95 Probably, still invested in them th...
# 54  1491288804870987776                                @TryingBrian stonks
# 55  1491288342977454080  @ali_moiz @patrickc @Stonks_dot_com Does this ...
# 56  1491287815552106499  RT @RudeKidzNFT: Here are the 25 winners, 25 o...
# 57  1491287286499397632  $FCEL so you got a loop. On stonk gives shares...
# 58  1491286908215099394  RT @RudeKidzNFT: Here are the 25 winners, 25 o...
# 59  1491286772076417024  @__stonks__ "pracownik jest częścią sklepu", c...
