# %%
import requests
import os
import json

# %%
# %run C:/Users/saswa/saswata/keys.py

# %%
print(bearer_token)
# Out:
# AAAAAAAAAAAAAAAAAAAAADspYwEAAAAAUqJiF7RG6Ba7AvZBCXWs1DRd9hk%3DFyL0rjcnOE0UPR163zP77mUPxakjrDfpILf3q8cZ4yVNBQETDy

# %%
search_url= 'https://api.twitter.com/2/tweets/search/recent?query=Finance&max_results=30'

# %%
r= requests.get(search_url, headers= {'Authorization': 'Bearer '+bearer_token})

# %%
print(r.json())
# Out:
# {'data': [{'id': '1491305850472132609', 'text': "It's a very wonderful project !!!! I feel avant-garde and sharpened sensibility!!!! I'm so happy if you give me this one that I'm going to incontinence good 🔥🔥🔥🚀🚀🚀🚀\n\n@Algold_Finance\n\n@alichia351\n@Lohrend7\n#2CrazyNFT #ESports #NFT #GamingPlatform #binance https://t.co/F6TTGvCMfj"}, {'id': '1491305849100197889', 'text': 'The @ExtendXYZ Genesis NFT Space Whitelist is Live! #IF IDIA https://t.co/v9w3I5umq9 #IDIA #Launchpad #BSC #BinanceSmartChain #Sol #Solana #ExtendXYZ #NFT #SolanaNFTs'}, {'id': '1491305846990848000', 'text': 'RT @5ireChain: #5ire is pleased to announce our partnership with @EagleRCapital. 🔥\n\nEaglerise Capital is a community-driven blockchain and…'}, {'id': '1491305842553290752', 'text': 'RT @JimmyHope_: @CallMeMatt By buying $OOE with it, really strong fundamentals and utilities , the ecosystem it belongs to offers users the…'}, {'id': '1491305841668272130', 'text': "RT @AsiaNews_FR: La #CoréeduNord 🇰🇵 finance so
# ...

# %%
dir(r)
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']

# %%
r_j= r.json()

# %%
type(r_j)
# Out:
# dict

# %%
print(len(r_j['data']))
# Out:
# 30

# %%
import pandas as pd

# %%
df= pd.DataFrame.from_dict(r_j['data'])

# %%
df
# Out:
#                      id                                               text
# 0   1491305850472132609  It's a very wonderful project !!!! I feel avan...
# 1   1491305849100197889  The @ExtendXYZ Genesis NFT Space Whitelist is ...
# 2   1491305846990848000  RT @5ireChain: #5ire is pleased to announce ou...
# 3   1491305842553290752  RT @JimmyHope_: @CallMeMatt By buying $OOE wit...
# 4   1491305841668272130  RT @AsiaNews_FR: La #CoréeduNord 🇰🇵 finance so...
# 5   1491305838073434118  RT @Lawtoken1: 📣#CoinTigerNewListing\n\n#LAW/U...
# 6   1491305836408639490  RT @MichaelPascoe01: Michael Pascoe: The timin...
# 7   1491305836299177984  RT @concretecodes: Two for Tuesday? Good to se...
# 8   1491305832528887817  RT @glawnetwork: @Lawtoken1\n \nCoin Market Ca...
# 9   1491305832080089088  RT @CryptoCrowd2011: ⚔️ AMA Series With https:...
# 10  1491305831555813379  RT @AtomElrond: Atomic Finance Token Elrond AI...
# ...

# %%
search_url= 'https://api.twitter.com/2/tweets/search/recent?query=Stonks&max_results=30'

# %%
r_2= requests.get(search_url, headers= {'Authorization': 'Bearer '+bearer_token})

# %%
df= df.append(pd.DataFrame.from_dict(r_2.json()['data']), ignore_index=True)

# %%
df
# Out:
#                      id                                               text
# 0   1491305850472132609  It's a very wonderful project !!!! I feel avan...
# 1   1491305849100197889  The @ExtendXYZ Genesis NFT Space Whitelist is ...
# 2   1491305846990848000  RT @5ireChain: #5ire is pleased to announce ou...
# 3   1491305842553290752  RT @JimmyHope_: @CallMeMatt By buying $OOE wit...
# 4   1491305841668272130  RT @AsiaNews_FR: La #CoréeduNord 🇰🇵 finance so...
# 5   1491305838073434118  RT @Lawtoken1: 📣#CoinTigerNewListing\n\n#LAW/U...
# 6   1491305836408639490  RT @MichaelPascoe01: Michael Pascoe: The timin...
# 7   1491305836299177984  RT @concretecodes: Two for Tuesday? Good to se...
# 8   1491305832528887817  RT @glawnetwork: @Lawtoken1\n \nCoin Market Ca...
# 9   1491305832080089088  RT @CryptoCrowd2011: ⚔️ AMA Series With https:...
# 10  1491305831555813379  RT @AtomElrond: Atomic Finance Token Elrond AI...
# ...

# %%
file_excel= "Stock_Tweets.xlsx"

# %%
df.to_excel(file_excel)
